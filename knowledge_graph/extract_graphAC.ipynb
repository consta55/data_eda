# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

## Input data directory
data_dir = "cureus"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Load Documents

# %%
loader = PyPDFLoader("/Users/andrea/Documents/git/KG/knowledge_graph/data_input/nutrients-12-02985.pdf")

# %%
## Dir PDF Loader
#loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
loader = PyPDFLoader("/Users/andrea/Documents/git/KG/knowledge_graph/data_input/nutrients-12-02985.pdf")
#loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages[3].page_content)
# Out:
# Number of chunks =  129
# Nutrients 2020 ,12, 2985 2 of 37
# to harbor PCa is important for early diagnosis and better prognosis [ 1]. PSA screening has signiﬁcantly
# increased the number of men treated for PCa, and it has been estimated that in ten years, many of them
# would remain asymptomatic, without experiencing PCa-speciﬁc mortality [ 2]. According to a recent
# meta-analysis, PSA screening was shown to produce a small reduction in 10-year disease-speciﬁc
# mortality, without any beneﬁts towards overall mortality [ 3]. As a result, most clinical practice
# guidelines do not advocate for a prostate biopsy based on elevated PSA concentrations alone [ 1,2,4],
# whereas based on the available evidence, the use of opportunistic routine PSA screening is also not
# recommended for all [ 1,2,5]. Nevertheless, elevated PSA concentrations usually require a second
# sample for veriﬁcation purposes, whereas persistent elevated PSA concentrations, are usually followed
# by prostate biopsy and diagnostic imaging [2,6].
# Since the antigen is not PCa-speciﬁc and can be a ﬀected by various factors, caution is required
# before relying on its diagnostic accuracy. It has been suggested than one in seven men undergoing PSA
# screening will demonstrate increased concentrations [ 2,7,8]. As a result, a controversy was sparked
# among experts on the usefulness of routine PSA screening. Some suggest that the use of PSA might
# reduce the relative risk for PCa by 9% [ 8], whereas others highlight its low impact on mortality, as well

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (129, 4)
#                                                 text  \
# 0  nutrients\nReview\nDietary Factors and Supplem...
# 1  6Division of Transplantation, Immunology and M...
# 2  prevention level. Despite the plethora of tria...
# 3  Nutrients 2020 ,12, 2985 2 of 37\nto harbor PC...
# 4  reduce the relative risk for PCa by 9% [ 8], w...
#
#                                               source  page  \
# 0  /Users/andrea/Documents/git/KG/knowledge_graph...     0
# 1  /Users/andrea/Documents/git/KG/knowledge_graph...     0
# 2  /Users/andrea/Documents/git/KG/knowledge_graph...     0
# 3  /Users/andrea/Documents/git/KG/knowledge_graph...     1
# 4  /Users/andrea/Documents/git/KG/knowledge_graph...     1
#
#                            chunk_id
# 0  0f86fc1b98b64455abdbe4255db938bf
# 1  eab662ea2f6b4848ba0f0969779954b7
# 2  8cf0dea016fd4833850a1a9b04bec10c
# 3  5681a50693e243ddb6d862737c2d1a44
# 4  bca094c78b634d92b615a210a6420226

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
regenerate = False

if regenerate:
    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# (521, 8)
#                       node_1                        node_2         edge  \
# 0                  nutrients            psa concentrations  Influencing
# 1            dietary factors            psa concentrations  Influencing
# 2            prostate cancer         increased cancer risk   Related to
# 3                     review  randomized controlled trials     Based on
# 4  maria g. grammatikopoulou      stefanos t. papageorgiou   Co-authors
#
#                            chunk_id node_3 node_4  weight  count
# 0  0f86fc1b98b64455abdbe4255db938bf    NaN    NaN     NaN      4
# 1  0f86fc1b98b64455abdbe4255db938bf    NaN    NaN     NaN      4
# 2  0f86fc1b98b64455abdbe4255db938bf    NaN    NaN     NaN      4
# 3  0f86fc1b98b64455abdbe4255db938bf    NaN    NaN     NaN      4
# 4  0f86fc1b98b64455abdbe4255db938bf    NaN    NaN     NaN      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                                 node_1              node_2  \
# 7049                                zn                  mc
# 7052                                zn                 pca
# 7060          α-receptor blocker (αrb)  psa concentrations
# 7061          α-receptor blocker (αrb)        saw palmetto
# 7066  γ-linolenic acid supplementation  psa concentrations
#
#                                                chunk_id  count  \
# 7049  7b1493c61dcc40e282c1933582edc1c2,7b1493c61dcc4...      2
# 7052  7b1493c61dcc40e282c1933582edc1c2,7b1493c61dcc4...      4
# 7060  82cfa82e61d745048bcb94c0cd7e367d,82cfa82e61d74...      3
# 7061  82cfa82e61d745048bcb94c0cd7e367d,82cfa82e61d74...      2
# 7066  565c34bc45d44907b525cc09410c464c,565c34bc45d44...      4
#
#                       edge
# 7049  contextual proximity
# 7052  contextual proximity
# 7060  contextual proximity
# 7061  contextual proximity
# 7066  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                                 node_1  \
# 0                                    *
# 1                                    *
# 2                                    *
# 3                                    *
# 4                                    *
# ...                                ...
# 2477                                zn
# 2478                                zn
# 2479          α-receptor blocker (αrb)
# 2480          α-receptor blocker (αrb)
# 2481  γ-linolenic acid supplementation
#
#                                                  node_2  \
# 0                                       dietary factors
# 1                                dimitrios p . bogdanos
# 2     division of transplantation, immunology and mu...
# 3                                 increased cancer risk
# 4                                 konstantinos gkiouras
# ...                                                 ...
# 2477                                                 mc
# 2478                                                pca
# 2479                                 psa concentrations
# 2480                                       saw palmetto
# 2481                                 psa concentrations
#
#                                                chunk_id  \
# 0     0f86fc1b98b64455abdbe4255db938bf,0f86fc1b98b64...
# 1     0f86fc1b98b64455abdbe4255db938bf,0f86fc1b98b64...
# 2     0f86fc1b98b64455abdbe4255db938bf,0f86fc1b98b64...
# 3     0f86fc1b98b64455abdbe4255db938bf,0f86fc1b98b64...
# 4     0f86fc1b98b64455abdbe4255db938bf,0f86fc1b98b64...
# ...                                                 ...
# 2477  7b1493c61dcc40e282c1933582edc1c2,7b1493c61dcc4...
# 2478  7b1493c61dcc40e282c1933582edc1c2,7b1493c61dcc4...
# 2479  82cfa82e61d745048bcb94c0cd7e367d,82cfa82e61d74...
# 2480  82cfa82e61d745048bcb94c0cd7e367d,82cfa82e61d74...
# 2481  565c34bc45d44907b525cc09410c464c,565c34bc45d44...
#
#                                                    edge  count
# 0                                  contextual proximity      2
# 1                                  contextual proximity      2
# 2                                  contextual proximity      2
# 3                                  contextual proximity      2
# 4                                  contextual proximity      2
# ...                                                 ...    ...
# 2477                               contextual proximity      2
# 2478  Studies have shown that low levels of zinc (Zn...      8
# 2479  Based on yet another Chinese meta-analysis, α-...      7
# 2480                               contextual proximity      2
# 2481                               contextual proximity      4
#
# [2482 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()

# %%
psa
# Out:
#                                                 node_1  \
# 14                                                 pca
# 15                                                 men
# 41                                                 psa
# 42                                                 psa
# 65                                      tomato extract
# 71                  tomato extract (30 mg of lycopene)
# 72                                    lycopene (15 mg)
# 73                                    lycopene (30 mg)
# 77                                            lycopene
# 135                                                psa
# 136                                                psa
# 159                                                psa
# 163                                          green tea
# 166  high-grade prostatic intraepithelial neoplasia...
# 167                                       men with pca
# 213                serum 25-hydroxyvitamin d (25(oh)d)
# 223                                                psa
# 229                                                psa
# 250                                                psa
# 251                                                psa
# 252                                                psa
# 253                                                psa
# 295                                         tamsulosin
# 308                                           selenium
# 309                                           curcumin
# 324                                            epa ons
# 349                               typical western diet
# 392                                                psa
# 393                                                psa
# 422                              body mass index (bmi)
# 424                                                psa
# 425                                                psa
# 426                                                psa
# 429                                                psa
#
#                                                 node_2  \
# 14                                                 psa
# 15                                                 psa
# 41                                         body weight
# 42                                       pca diagnosis
# 65                                                 psa
# 71                                                 psa
# 72                                                 psa
# 73                                                 psa
# 77                                                 psa
# 135                                                psa
# 136                           serum psa concentrations
# 159                                           decrease
# 163                                                psa
# 166                                                psa
# 167                                                psa
# 213                                                psa
# 223                                     adenocarcinoma
# 229                                             trials
# 250                                      prevent trial
# 251                                       select trial
# 252                              high lycopene sources
# 253  saw palmetto, selenium, and lycopene or tamsul...
# 295                                                psa
# 308                                                psa
# 309                                                psa
# 324                                                psa
# 349                                                psa
# 392                                                pca
# 393                            high psa concentrations
# 422                                                psa
# 424                                                age
# 425                                    body mass index
# 426                                                psa
# 429                                    body mass index
#
#                                                   edge  \
# 14   PCa and PSA are both related to prostate healt...
# 15   Identifying men most likely to have elevated l...
# 41   In the given context, it is mentioned that wit...
# 42   The text states that the reduction in PSA with...
# 65   Consumption of tomato extract (30 mg of lycope...
# 71   Consumption of tomato extract (30 mg of lycope...
# 72   Supplementation with lycopene (15 mg) for appr...
# 73   Supplementation with lycopene (30 mg) for appr...
# 77   decreased PSA concentrations observed in inter...
# 135  Increased in both groups over the intervention...
# 136             Remained unchanged in Adams [98] study
# 159  In the GTCs arm, a reduction was noted in PSA ...
# 163  Daily consumption of green tea on the weeks pr...
# 166  Daily GTCs supplementation for a year decrease...
# 167  Daily consumption of green tea on the weeks pr...
# 213  indicates an inverse relationship in some cros...
# 223                expression of PSA in adenocarcinoma
# 229  Most RCTs suggested a lack of efficacy of vita...
# 250  The PREVENT trial compared 400 IU vitamin E ON...
# 251  According to the Selenium and Vitamin E Cancer...
# 252  When men at risk for PCa were recruited (Table...
# 253  Similarly, no differences were noted when men ...
# 295  In both groups, there was no significant diffe...
# 308  Combined supplementation with selenium failed ...
# 309  When the combined ONS included curcumin, resve...
# 324  In a Japanese trial without a comparator inter...
# 349  was compared to a low fat /ﬁsh oil (LFFO) diet...
# 392  The mean PSADT for the intervention participan...
# 393  No diﬀerence was observed in the distributions...
# 422  Harrison et al. (2017) investigated the relati...
# 424  Investigating the prostate specific antigen, b...
# 425  Investigating the prostate specific antigen, b...
# 426  Systematic review and meta-analysis of the ass...
# 429  Presurgical weight loss a affects tumour trait...
#
#                              chunk_id node_3 node_4  weight  count
# 14   8cf0dea016fd4833850a1a9b04bec10c    NaN    NaN     NaN      4
# 15   8cf0dea016fd4833850a1a9b04bec10c    NaN    NaN     NaN      4
# 41   60222cf731ee4261aa55673b1bcfbc87    NaN    NaN     NaN      4
# 42   60222cf731ee4261aa55673b1bcfbc87    NaN    NaN     NaN      4
# 65   aade5cfe0ef34b1e850beb9b58a88fa7    NaN    NaN     NaN      4
# 71   aade5cfe0ef34b1e850beb9b58a88fa7    NaN    NaN     NaN      4
# 72   aade5cfe0ef34b1e850beb9b58a88fa7    NaN    NaN     NaN      4
# 73   aade5cfe0ef34b1e850beb9b58a88fa7    NaN    NaN     NaN      4
# 77   ebcab93107c24944afbde28707c461a7    NaN    NaN     NaN      4
# 135  1c78cba035994466bf189143eb39ed63    NaN    NaN     NaN      4
# 136  1c78cba035994466bf189143eb39ed63    NaN    NaN     NaN      4
# 159  b6b4dbf117fe465fbb6cb5d672c1b4d8    NaN    NaN     NaN      4
# 163  385cd8038dcb4c3a96edcb738c7ed013    NaN    NaN     NaN      4
# 166  385cd8038dcb4c3a96edcb738c7ed013    NaN    NaN     NaN      4
# 167  385cd8038dcb4c3a96edcb738c7ed013    NaN    NaN     NaN      4
# 213  8e721f97143a4f13b98917fd95241f90    NaN    NaN     NaN      4
# 223  c6f9a01301b047ff847fd761c4e07fef    NaN    NaN     NaN      4
# 229  a1120799d0a9435c977e7c3bfdaae545    NaN    NaN     NaN      4
# 250  fd45ed8373e1443cbd5d37a694c96736    NaN    NaN     NaN      4
# 251  fd45ed8373e1443cbd5d37a694c96736    NaN    NaN     NaN      4
# 252  fd45ed8373e1443cbd5d37a694c96736    NaN    NaN     NaN      4
# 253  fd45ed8373e1443cbd5d37a694c96736    NaN    NaN     NaN      4
# 295  0364a1f4e761408d9311c73cdaea96ff    NaN    NaN     NaN      4
# 308  fd898b4f3c72463f9e9ec08be64b51b3    NaN    NaN     NaN      4
# 309  fd898b4f3c72463f9e9ec08be64b51b3    NaN    NaN     NaN      4
# 324  d1fa2063678240cb937cea270ac1f7a9    NaN    NaN     NaN      4
# 349  b6023554af5e4098983a53386838d451    NaN    NaN     NaN      4
# 392  63942748587f41f6931fb8fc6bd52141    NaN    NaN     NaN      4
# 393  63942748587f41f6931fb8fc6bd52141    NaN    NaN     NaN      4
# 422  6d511f5bd7dc49d2ba38ee56a2510cf5    NaN    NaN     NaN      4
# 424  d2b200caed8a4814a8f3ee302e349efe    NaN    NaN     NaN      4
# 425  d2b200caed8a4814a8f3ee302e349efe    NaN    NaN     NaN      4
# 426  d2b200caed8a4814a8f3ee302e349efe    NaN    NaN     NaN      4
# 429  d2b200caed8a4814a8f3ee302e349efe    NaN    NaN     NaN      4

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (547,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg1.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  114
# [['*', 'dimitrios p . bogdanos', 'konstantinos gkiouras'], ['1000 iu vitamin d', '12, 2985', '2 x 2 pomx caps', '2000 iu vitamin d', '4000 iu vitamin d', '5-alpha-reductase inhibitors', '60 mg sulforaphane ons', '8 oz liquid pomx', '[90]', '[91]', 'adenocarcinoma', 'agaricus blazei murill', 'age', 'ala', 'androgen axis', 'androgen deprivation therapy', 'animal studies', 'antioxidant ons', 'antioxidants', 'antwi', 'as', 'as for disease management', 'below 0.2 ng/ml', 'benign prostate hyperplasia', 'benign prostatic hyperplasia', 'better prognosis', 'biopsy-proven pca', 'bmi', 'body mass index', 'body mass index (bmi)', 'body weight', 'bosland', 'bph', 'calcitriol', 'caloric restriction', 'cancer inhibitory potential', 'cernitin', 'cicero', 'cipolla', 'combined antioxidant supplementation', 'combined epa and dha supplementation', 'combined supplementation', 'combined tamsulosin and saw palmetto therapy', 'concord grape juice', 'consumed bread again as a medium for supplementation', 'consumed whole grain and bran products, substituting 50% of their daily total energy intake (tei)', 'counseling', 'cranberries', 'curcumin', 'curcumin ons', 'daidzein', 'decrease', 'delivery of dietary and cooking classes', 'diet', 'dietary factors', 'dietary intake of eicosapentaenoic (epa; 20:5n −3), docosahexaenoic (dha; 22:6n −3)', 'dietary patterns', 'dietary supplements', 'disease progression', 'docetaxel', 'early diagnosis', 'ebrt', 'epa', 'epa ons', 'epa supplementation', 'epigenetic modulators for prostate cancer prevention', 'escalating doses of vitamin d 3', 'evidence', 'examining the effect of phytoestrogen ons on psa concentrations among men with pca, or increased pca risk.', 'eﬅacy', 'favorable changes', 'flavonoids', 'fruit and fruit extracts', 'fruits', 'ganoderma lucidum', 'genistein', 'grape juice antioxidants', 'grape skin and seeds extract', 'green tea', 'gtcs', 'gtcs alternative', 'gtcs caps', 'healthy dietary patterns', 'hgpin', 'high lycopene sources', 'high psa concentrations', 'high-grade prostatic intraepithelial neoplasia (hgpin) and /or atypical small acinar proliferation (asap)', 'high-soy diet', 'histologically confirmed pca', 'inflammation', 'inflammation, prostatic cell growth, and stimulation of the apoptotic machinery', 'initial psa', 'intervention participants', 'iv docetaxel', 'kumar', 'lffo diet', 'low carbohydrate diets', 'lower urinary tract symptoms', 'lower-dose walnut supplementation', 'lycopene', 'lycopene (15 mg)', 'lycopene (30 mg)', 'lycopene ons', 'malignancy', 'marine fatty acid supplementation', 'mc', 'meat and dairy products', 'men', 'men electing prostatectomy for prostate cancer', 'men on active surveillance (as)', 'men on androgen deprivation therapy', 'men scheduled for radical prostatectomy', 'men with pca', 'mhgpin', 'mixed antioxidant therapy', 'mushroom immunology', 'mv', 'no di ﬀerences were noted in the psa concentrations of participants in both groups', 'no intervention', 'non-prescribed antioxidant supplements', 'nutrients', 'nutrients 2020', 'obese men', 'one in seven men undergoing psa screening demonstrates increased concentrations', 'oral curcumin', 'overweight men', 'pca', 'pca diagnosis', 'pca incidence', 'pca or advanced pca risk', 'pca prevention', 'pca recurrence after prostatectomy', 'pca risk', 'pca therapy', 'pca-mortality', 'pca-rcts', 'permixon', 'phytochemicals', 'pin', 'placebo', 'placebo groups', 'placebo ons', 'plant compounds', 'polye', 'polyphenols', 'pomx', 'prevent trial', 'primary prevention of prostate cancer', 'procomb trial', 'prostate cancer patients prior to radical prostatectomy', 'prostate cancer prevention', 'prostate cancer treatment', 'prostate size', 'prostatectomy', 'prostatectomyn', 'prostatic intraepithelial neoplasia', 'protective effects against cancer and vascular diseases', 'psa', 'psa concentrations', 'psa concentrations among men with pca, increased pca risk, or bph', 'psa kinetics', 'psa results', 'psa thresholds for testing for prostate cancer', ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                                   node    color  group
# 0                                                    *  #9057db      1
# 1                               dimitrios p . bogdanos  #9057db      1
# 2                                konstantinos gkiouras  #9057db      1
# 3                                    1000 iu vitamin d  #dbb957      2
# 4                                             12, 2985  #dbb957      2
# ..                                                 ...      ...    ...
# 542                                   specific cancers  #57dbce    112
# 543  soy pro beverages with high micronutrient content  #dadb57    113
# 544                                              urban  #dadb57    113
# 545                           tomato oleoresin extract  #ce57db    114
# 546                                         tumor size  #ce57db    114
#
# [547 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index2.html"

net = Network(
    notebook=True,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=True,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
#net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
#net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index2.html

# %%
net.write_html('./docs/index.html',open_browser=True)

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=True,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)
